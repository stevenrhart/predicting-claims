# %% [markdown]
# # Predicting Pet Insurance Claims - EDA
#
# ## 1 Introduction
#
# ### 1.1 Background
# Whenever a pet insurance policy holder incurs veterinary expenses related to their enrolled pet, they can submit claims for reimbursement, and the insurance company reimburses eligible expenses. To price insurance products correctly, the insurance company needs to have a good idea of the amount their policy holders are likely to claim in the future.
#
# ### 1.2 Project Goal
# The goal of this project is to create a machine learning model to predict how much (in dollars) a given policy holder will claim for during the second year of their policy.
#
# ### 1.3 Initial Questions for EDA
# Below are a few initial questions to answer and areas of interest for the detailed data analysis.
# * What patterns or relationships exist between 'Breed' and amounts claimed?
# * What patterns or relationships exist between 'Species' and amounts claimed?
# * Decide what to do about the very high (claims > \\$10k) and very low (claims = \$0) claims amounts
# * Determine if EnrollPath is worth keeping or if there is any correlation between EnrollPath and claims amounts
# * Look for connection between PetAge and number/amount of claims
#
# Some opportunities for additional feature engineering:
# * Scrape web and/or find data set for dog breed average weights to include as a new column
# * Scrape web and/or find data set for average lifespan by breed and merge in as a new column
#     * Create new feature for PctLifespanYr1 and PctLifeSpanYr2 to calculate pet age in year 1 and year 2 as a percentage of the average lifespan based on the breed
#     * If above steps are completed, consider encoding breed, based on AvgWeight and AvgLifespan, into a new feature as a means of converting Breed from an object column to a numeric column

# %% [markdown]
# # 2 Setup
#
# ## 2.1 Imports

# %%
import pandas as pd
import numpy as np
from scipy import stats

# import random

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## 2.2 Data Load & Preview

# %%
# Read in the data file generated during data wrangling
df = pd.read_csv('../data/merged_pets.csv', index_col='PetId')

# Preview
df.head()
# Out:
#       Species               Breed  Premium  Deductible EnrollPath  AgeYr1  \
# PetId
# 0         Dog  Schnauzer Standard    84.54         200        Web       3
# 1         Dog           Yorkiepoo    50.33         500      Phone       0
# 2         Dog  Mixed Breed Medium    74.00         500      Phone       0
# 3         Dog  Labrador Retriever    57.54         500      Phone       0
# 4         Dog      French Bulldog    60.69         700        Web       0
#
#        AgeYr2  YoungAge  MixedBreed  AmtClaimsYr1  AmtClaimsYr2  AvgClaimsYr1  \
# PetId
# 0           4         0           0          0.00       1242.00      0.000000
# 1           1         0           0          0.00          0.00      0.000000
# 2           1         0           1        640.63       1187.68    213.543333
# 3           1         0           0          0.00          0.00      0.000000
# 4           1         0           0       7212.25        168.75    801.361111
#
#        AvgClaimsYr2  NumClaimsYr1  NumClaimsYr2  NumClaimsTotal  \
# PetId
# 0           621.000             0             2               2
# 1             0.000             0             0               0
# 2           237.536             3             5               8
# 3             0.000             0             0               0
# 4           168.750             9             1              10
#
#        AmtClaimsTotal  AvgClaimsTotal
# PetId
# 0             1242.00       621.00000
# 1                0.00         0.00000
# 2             1828.31       228.53875
# 3                0.00         0.00000
# 4             7381.00       738.10000

# %% [markdown]
# # 3 Species and Breed
#
# ## 3.1 Species Analysis
# As a starting point, let's look at a breakdown of the data by species to see if we see any significant differences in our other data points when viewed through the species lens.
#
# Is there a significant difference in claims amounts between cats and dogs?

# %%
# Group df by 'Species' and view column means
df.groupby(by='Species').agg('mean')
# Out:
#            Premium  Deductible    AgeYr1    AgeYr2  YoungAge  MixedBreed  \
# Species
# Cat      43.583218  433.969965  2.149801  3.149801  0.005234    0.192049
# Dog      67.905494  506.687512  1.250810  2.250810  0.007647    0.268272
#
#          AmtClaimsYr1  AmtClaimsYr2  AvgClaimsYr1  AvgClaimsYr2  NumClaimsYr1  \
# Species
# Cat        432.760201    444.637845    150.436436    136.365279      0.902293
# Dog        867.228391    739.179708    237.679717    196.448307      1.803983
#
#          NumClaimsYr2  NumClaimsTotal  AmtClaimsTotal  AvgClaimsTotal
# Species
# Cat          0.829511        1.731805      877.398046      228.249569
# Dog          1.554912        3.358896     1606.408099      317.476544

# %% [markdown]
# ### 3.1.1 Initial observations
# Some initial observations based on the breakdown above:
# 1. On average, Dogs have higher premiums and higher deductibles
# 2. Claims data - number of claims, average claim, total claims - is higher for dogs in all categories
#
# The difference in the average claims amounts between cats and dogs in year two is just under \\$300 (i.e., \\$445 for cats and \\$739 for dogs). And the average total claims amount for both years combined is nearly twice as large for dogs (\\$1600) as for cats (\$877). Based on this, we may need to factor this in to our predictive model later on as it appears that a single model may not work well across the two species.
#
# Before we make the final decision, let's take a look and see if the difference is as significant as it appears.

# %% [markdown]
# ### 3.1.2 Is there a significant difference between the claims amounts in year 2 between cats and dogs?
#
# **TODO - Decide if to include this analysis and if so, will need to clean up and streamline.**
# To answer this question, we can do some analysis to test the significance of our current values. This will help us to understand the liklihood that this difference in premium amounts could be the result of random chance alone.
#
# Here's an outline of the process we'll follow to answer the question:
# 1. We'll assume that species has no impact on claims amounts
#
# 2. Given this assumption, we should be able to replicate a similiar difference in the mean claims amounts for cats and dogs in year 2 when compared to the one we observe in the data (\\$300) just by:
# a. Shuffling the 'AmtClaimsYr2' column
# b. Keeping the 'Species' column the same
# c. Calculating the difference between the mean claims amount for year 2 between cats and dogs
#
# 3. We can then repeat this process each time calculating the difference in mean values between the two species
#
# 4. Once we have the difference in means for each permutation, we can take the mean of all these differences, and this will be called our permutation difference. The permutation difference will help us understand if the difference between species really is significant or not.
#
# #### 3.1.2.1 Subsetting the data
# First, since our main interest is to look at claims amounts for year 2, we'll subset our data to consist of only two columns - 'Species' and 'AmtClaimsYr2'.

# %%
# Subset the data
subset = df[['Species', 'AmtClaimsYr2']].copy()

# Preview
subset.head()
# Out:
#       Species  AmtClaimsYr2
# PetId
# 0         Dog       1242.00
# 1         Dog          0.00
# 2         Dog       1187.68
# 3         Dog          0.00
# 4         Dog        168.75

# %%
# Create a column called `Permutation1`, and assign to it the result of permuting (shuffling) the AmtClaimsYr2 column
# This assignment will use our numpy object's random.permutation() method
subset["Permutation1"] = np.random.permutation(subset.AmtClaimsYr2)

# Call the describe() method on our permutation grouped by 'species'. 
subset.Permutation1.describe()
# Out:
# count    50000.000000
# mean       691.911630
# std       2242.769687
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        412.212500
# max      70251.600000
# Name: Permutation1, dtype: float64

# %%
# Lets compare with the previous analytical summary:
subset.groupby(by=["Species"]).Permutation1.mean()
# Out:
# Species
# Cat    680.586241
# Dog    694.076555
# Name: Permutation1, dtype: float64

# %%
# The difference in the means for Permutation1 (0.001103) now looks hugely different to our observed difference of 0.14206. 
# It's sure starting to look like our observed difference is significant, and that the Null is false; platform does impact on ratings
# But to be sure, let's create 10,000 permutations, calculate the mean ratings for Google and Apple apps and the difference between these for each one, and then take the average of all of these differences.
# Let's create a vector with the differences - that will be the distibution of the Null.

# First, make a list called difference.
difference = np.empty(10000)

# Now make a for loop that does the following 10,000 times:
# 1. makes a permutation of the 'Rating' as you did above
# 2. calculates the difference in the mean rating for apple and the mean rating for google. 
for i in range(10000):
    subset["Permutation"] = np.random.permutation(subset.AmtClaimsYr2)
    diff = np.mean(subset[subset.Species == 'Cat'].Permutation) - np.mean(subset[subset.Species == 'Dog'].Permutation)
    difference[i] = diff

# %%
# Make a variable called 'histo', and assign to it the result of plotting a histogram of the difference list. 
histo = plt.hist(difference)

# %%
# Now make a variable called obs_difference, and assign it the result of the mean of our 'apple' variable and the mean of our 'google variable'
obs_difference = np.mean(subset[subset.Species == 'Cat'].AmtClaimsYr2) - np.mean(subset[subset.Species == 'Dog'].AmtClaimsYr2)

# Make this difference absolute with the built-in abs() function. 
obs_difference = abs(obs_difference)

# Print out this value; it should be 0.1420605474512291. 
print(obs_difference)
# Out:
# 294.54186271398044

# %%
np.sum(difference >= obs_difference) / len(difference)
# Out:
# 0.0

# %% [markdown]
# So actually, zero differences are at least as extreme as our observed difference!
#
# So the p-value of our observed data is 0.
#
# It doesn't matter which significance level we pick; our observed data is statistically significant, and we reject the Null.
#
# We conclude that Species does impact on claims amounts and our model will need to account for this moving forward.

# %% [markdown]
# ## Other species related analysis

# %%
cats = df[df.Species == 'Cat'].copy()
dogs = df[df.Species == 'Dog'].copy()

# %%
cats.AmtClaimsYr2.describe()
# Out:
# count     8024.000000
# mean       444.637845
# std       1933.711048
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      70251.600000
# Name: AmtClaimsYr2, dtype: float64

# %%
dogs.AmtClaimsYr2.describe()
# Out:
# count    41976.000000
# mean       739.179708
# std       2294.107457
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        483.440000
# max      58392.140000
# Name: AmtClaimsYr2, dtype: float64

# %%
print("95% of cat claims in year 2 are below " + str(round(cats.AmtClaimsYr2.quantile(0.95), 2)))
print("95% of dog claims in year 2 are below " + str(round(dogs.AmtClaimsYr2.quantile(0.95), 2)))
# Out:
# 95% of cat claims in year 2 are below 2314.99
# 95% of dog claims in year 2 are below 3816.5

# %% [markdown]
# ## Correlation between Yr2 claims and other features

# %%
cats_corr = cats.corr()
dogs_corr = dogs.corr()

# %%
cats_corr
# Out:
#                  Premium  Deductible    AgeYr1    AgeYr2  YoungAge  \
# Premium         1.000000   -0.329189  0.462401  0.462401 -0.010162
# Deductible     -0.329189    1.000000  0.271772  0.271772 -0.029727
# AgeYr1          0.462401    0.271772  1.000000  1.000000 -0.050391
# AgeYr2          0.462401    0.271772  1.000000  1.000000 -0.050391
# YoungAge       -0.010162   -0.029727 -0.050391 -0.050391  1.000000
# MixedBreed     -0.014634    0.025892  0.043772  0.043772  0.008479
# AmtClaimsYr1    0.098459   -0.027339  0.040875  0.040875  0.006886
# AmtClaimsYr2    0.119203   -0.033331  0.056472  0.056472 -0.003680
# AvgClaimsYr1    0.089318   -0.028875  0.050250  0.050250 -0.007488
# AvgClaimsYr2    0.107789   -0.028030  0.054367  0.054367 -0.004256
# NumClaimsYr1    0.099103   -0.071139  0.023696  0.023696  0.015547
# NumClaimsYr2    0.137941   -0.052148  0.088482  0.088482  0.006109
# NumClaimsTotal  0.141798   -0.072593  0.068473  0.068473  0.012572
# AmtClaimsTotal  0.142778   -0.039815  0.064402  0.064402  0.001163
# AvgClaimsTotal  0.109068   -0.020840  0.058322  0.058322 -0.008309
#
#                 MixedBreed  AmtClaimsYr1  AmtClaimsYr2  AvgClaimsYr1  \
# Premium          -0.014634      0.098459      0.119203      0.089318
# Deductible        0.025892     -0.027339     -0.033331     -0.028875
# AgeYr1            0.043772      0.040875      0.056472      0.050250
# AgeYr2            0.043772      0.040875      0.056472      0.050250
# YoungAge          0.008479      0.006886     -0.003680     -0.007488
# MixedBreed        1.000000     -0.008596      0.000568      0.003770
# AmtClaimsYr1     -0.008596      1.000000      0.177116      0.682642
# AmtClaimsYr2      0.000568      0.177116      1.000000      0.101741
# AvgClaimsYr1      0.003770      0.682642      0.101741      1.000000
# AvgClaimsYr2     -0.001179      0.096761      0.687651      0.091968
# NumClaimsYr1     -0.017063      0.673016      0.177872      0.301320
# NumClaimsYr2     -0.005409      0.287061      0.614115      0.115635
# NumClaimsTotal   -0.012990      0.558284      0.482804      0.241926
# AmtClaimsTotal   -0.004408      0.691297      0.833587      0.457837
# AvgClaimsTotal   -0.002858      0.449081      0.494685      0.662744
#
#                 AvgClaimsYr2  NumClaimsYr1  NumClaimsYr2  NumClaimsTotal  \
# Premium             0.107789      0.099103      0.137941        0.141798
# Deductible         -0.028030     -0.071139     -0.052148       -0.072593
# AgeYr1              0.054367      0.023696      0.088482        0.068473
# AgeYr2              0.054367      0.023696      0.088482        0.068473
# YoungAge           -0.004256      0.015547      0.006109        0.012572
# MixedBreed         -0.001179     -0.017063     -0.005409       -0.012990
# AmtClaimsYr1        0.096761      0.673016      0.287061        0.558284
# AmtClaimsYr2        0.687651      0.177872      0.614115        0.482804
# AvgClaimsYr1        0.091968      0.301320      0.115635        0.241926
# AvgClaimsYr2        1.000000      0.079470      0.297132        0.229883
# NumClaimsYr1        0.079470      1.000000      0.418711        0.824655
# NumClaimsYr2        0.297132      0.418711      1.000000        0.858957
# NumClaimsTotal      0.229883      0.824655      0.858957        1.000000
# AmtClaimsTotal      0.559167      0.508328      0.611986        0.667807
# AvgClaimsTotal      0.721391      0.184486      0.193323        0.224437
#
#                 AmtClaimsTotal  AvgClaimsTotal
# Premium               0.142778        0.109068
# Deductible           -0.039815       -0.020840
# AgeYr1                0.064402        0.058322
# AgeYr2                0.064402        0.058322
# YoungAge              0.001163       -0.008309
# MixedBreed           -0.004408       -0.002858
# AmtClaimsYr1          0.691297        0.449081
# AmtClaimsYr2          0.833587        0.494685
# AvgClaimsYr1          0.457837        0.662744
# AvgClaimsYr2          0.559167        0.721391
# NumClaimsYr1          0.508328        0.184486
# NumClaimsYr2          0.611986        0.193323
# NumClaimsTotal        0.667807        0.224437
# AmtClaimsTotal        1.000000        0.615239
# AvgClaimsTotal        0.615239        1.000000

# %% [markdown]
# Total and average claims are highly correlated with yr1 and yr2 totals and averages, respectively. This makes sense. Some additional areas for analysis include:
#
# 1. Investigate to see if high yr1 claims tend to lead to high yr2 claims, or if there is any connection. (correlation is only 0.177)
#
# 2.

# %%
plt.figure(figsize=(10,6))
_ = sns.heatmap(cats_corr)
plt.show()

# %%
plt.figure(figsize=(10,6))
_ = sns.heatmap(dogs_corr)
plt.show()

# %% [markdown]
# ## Breed analysis

# %%
# Groupby Breed column and aggregate the mean of the total claims amount
breed_claims = df.groupby(by=['Species', 'Breed']).AmtClaimsTotal.agg(['mean', 'count']).sort_values(by='mean',
                                                                                        ascending=False)
# Rename aggregate columns 
breed_claims.rename(columns={"mean": "AvgTotalClaims", "count": "BreedCount"}, inplace=True)

# Preview descriptive statistics 
breed_claims.describe()
# Out:
#        AvgTotalClaims   BreedCount
# count      373.000000   373.000000
# mean      1765.657092   134.048257
# std       2435.361667   435.819051
# min          0.000000     1.000000
# 25%        746.456534     4.000000
# 50%       1227.918333    14.000000
# 75%       1999.970244    73.000000
# max      25578.190000  4653.000000

# %%
breed_claims.head(50)
# Out:
#                                     AvgTotalClaims  BreedCount
# Species Breed
# Cat     Selkirk Rex                   25578.190000           1
# Dog     Bergamasco Sheepdog           21981.270000           1
#         Tibetan Mastiff               19668.195000           2
#         Akbash Dog                    11383.600000           1
#         American Mastiff              11064.570000           1
#         St Johns Waterdog              9868.480000           1
# Cat     Colorpoint Shorthair           9806.425000           2
# Dog     Mi Ki                          7556.816667           6
#         Perro de Presa Canario         7225.331429           7
#         Dogue de Bordeaux              6343.498333          12
#         Central Asian Shepherd         5870.580000           3
#         Scottish Deerhound             5825.647500           4
#         Clumber Spaniel                5779.530000           7
#         Bantam Bulldog                 5438.790000           1
#         Old Boston Bulldogge           5110.556667           6
#         Anatolian Shepherd             5060.245714           7
#         Miniature Bull Terrier         4949.283846          13
#         Cirneco dell Etna              4855.720000           2
#         Wirehair Vizsla                4498.066667           6
# Cat     LaPerm                         4487.820000           1
# Dog     Norfolk Terrier                4465.363333           3
#         Kuvasz                         4449.356000           5
#         Bull Terrier Standard          4403.142500           8
#         Dingo Carolina                 4243.761667           6
#         English Foxhound               4200.486667           3
#         Black Russian Terrier          4139.972500           8
#         Bloodhound                     3851.571538          26
#         American Water Spaniel         3738.825000           4
#         English Bulldog                3672.979688         481
#         Olde English Bulldog           3641.280254         118
#         Irish Wolfhound                3604.366610          59
#         Flat Coated Retriever          3547.109118          34
#         American Foxhound              3541.542857           7
#         Glen of Imaal Terrier          3536.820000           1
#         Mastiff                        3498.422308          26
#         Beauceron                      3435.771429          14
#         Newfoundland                   3422.989159         107
#         American Bully                 3409.193191          47
#         Shar Pei                       3294.443077          39
#         Lakeland Terrier               3270.112000           5
#         Polish Lowland Sheepdog        3264.488000           5
#         Pointer                        3240.263478          23
#         Komondor                       3179.650000           1
#         Springer Spaniel               3134.781579          19
#         Alaskan Malamute               3096.346719          64
#         Hovawart                       3081.735000           2
#         Finnish Lapphund               3012.030000           1
#         Argentine Dogo                 3011.587333          15
#         Greater Swiss Mountain Dog     2996.385000          40
#         Malinois Belgian Shepherd      2946.804286           7

# %%
breed_claims.tail(20)
# Out:
#                                AvgTotalClaims  BreedCount
# Breed
# Bavarian Mountain Hound                   0.0           1
# Canaan Dog                                0.0           1
# Caucasian Ovcharka                        0.0           1
# Australian Stumpy Tail Cattle             0.0           1
# Cesky Terrier                             0.0           2
# Chartreux                                 0.0           1
# Large Munsterlander                       0.0           1
# Chipoo                                    0.0           2
# Pharaoh Hound                             0.0           2
# Japanese Spitz                            0.0           1
# Skye Terrier                              0.0           1
# Nebelung                                  0.0           3
# Irish Water Spaniel                       0.0           1
# Pyrenees Braque Francais                  0.0           2
# Icelandic sheepdog                        0.0           1
# Ibizan Hound                              0.0           1
# Appenzeller Sennenhunde                   0.0           1
# American Wirehair                         0.0           1
# Pyrenean Shepherd                         0.0           1
# Pixiebob                                  0.0          10

# %%
cond_plot = sns.FacetGrid(data=cats, col='Breed', hue='CentralAir', col_wrap=4)
cond_plot.map(sns.scatterplot, 'OverallQual', 'SalePrice');

# %% [markdown]
# ## EnrollPath - Do people who enroll on the web submit more claims on average than those enrolling by phone?
#
# Does enrollpath matter in terms of number of claims filed?
# Look at median claims

# %%
df.EnrollPath.value_counts()
# Out:
# Web      25486
# Phone    23525
# EB         989
# Name: EnrollPath, dtype: int64

# %%
enrollpath = df.groupby(by='EnrollPath')
enrollpath.NumClaimsTotal.agg(['mean', 'median', 'min', 'max'])
# Out:
#                 mean  median  min  max
# EnrollPath
# EB          2.878665       1    0   99
# Phone       3.405016       1    0  151
# Web         2.822687       1    0  106

# %%
enrollpath.head()
# Out:
#       Species               Breed  Premium  Deductible EnrollPath  AgeYr1  \
# PetId
# 0         Dog  Schnauzer Standard    84.54         200        Web       3
# 1         Dog           Yorkiepoo    50.33         500      Phone       0
# 2         Dog  Mixed Breed Medium    74.00         500      Phone       0
# 3         Dog  Labrador Retriever    57.54         500      Phone       0
# 4         Dog      French Bulldog    60.69         700        Web       0
# 5         Dog            Shih Tzu    43.53         700      Phone       2
# 6         Cat  American Shorthair    47.40         250        Web       0
# 7         Dog               Boxer    75.14         700        Web       5
# 8         Cat   Domestic Longhair    24.52         250      Phone       2
# 9         Dog   Mixed Breed Small    41.07         500        Web       1
# 34        Cat  Domestic Shorthair    39.75         700         EB      10
# 52        Dog  Mixed Breed Medium   197.37           0         EB       6
# 76        Dog    Poodle Miniature    39.17          75         EB       7
# 82        Cat  American Shorthair    32.71          75         EB       6
# 101       Dog   Doberman Pinscher    50.44          75         EB       4
#
#        AgeYr2  YoungAge  MixedBreed  AmtClaimsYr1  AmtClaimsYr2  AvgClaimsYr1  \
# PetId
# 0           4         0           0          0.00       1242.00      0.000000
# 1           1         0           0          0.00          0.00      0.000000
# 2           1         0           1        640.63       1187.68    213.543333
# 3           1         0           0          0.00          0.00      0.000000
# 4           1         0           0       7212.25        168.75    801.361111
# 5           3         0           0       2665.67          0.00    296.185556
# 6           1         0           0          0.00        811.38      0.000000
# 7           6         0           0       2873.47       2497.03    410.495714
# 8           3         0           0          0.00          0.00      0.000000
# 9           2         0           1          0.00          0.00      0.000000
# 34         11         0           0          0.00       3037.67      0.000000
# 52          7         0           1       4826.80        705.09   1608.933333
# 76          8         0           0          0.00          0.00      0.000000
# 82          7         0           0        163.50          0.00    163.500000
# 101         5         0           0          0.00          0.00      0.000000
#
#        AvgClaimsYr2  NumClaimsYr1  NumClaimsYr2  NumClaimsTotal  \
# PetId
# 0        621.000000             0             2               2
# 1          0.000000             0             0               0
# 2        237.536000             3             5               8
# 3          0.000000             0             0               0
# 4        168.750000             9             1              10
# 5          0.000000             9             0               9
# 6        811.380000             0             1               1
# 7        356.718571             7             7              14
# 8          0.000000             0             0               0
# 9          0.000000             0             0               0
# 34       607.534000             0             5               5
# 52       117.515000             3             6               9
# 76         0.000000             0             0               0
# 82         0.000000             1             0               1
# 101        0.000000             0             0               0
#
#        AmtClaimsTotal  AvgClaimsTotal
# PetId
# 0             1242.00      621.000000
# 1                0.00        0.000000
# 2             1828.31      228.538750
# 3                0.00        0.000000
# 4             7381.00      738.100000
# 5             2665.67      296.185556
# 6              811.38      811.380000
# 7             5370.50      383.607143
# 8                0.00        0.000000
# 9                0.00        0.000000
# 34            3037.67      607.534000
# 52            5531.89      614.654444
# 76               0.00        0.000000
# 82             163.50      163.500000
# 101              0.00        0.000000

# %% [markdown]
# ## How much does age play a roll in yr2 claims totals?
# 1. Look at average claims amount grouped by age in years
# 2. Scatterplot of AgeYr2 and AmtClaimsYr2 (maybe do this all up and also a facetgrid with a plot per year)
# 3.

# %%
age_claims = df.groupby(by='AgeYr2').AmtClaimsYr2.agg('mean')
age_claims
# Out:
# AgeYr2
# 1      654.997407
# 2      522.944095
# 3      589.970523
# 4      627.048285
# 5      613.559708
# 6      951.294075
# 7     1086.549466
# 8     1148.739892
# 9     1043.776996
# 10    1224.502117
# 11    1398.799773
# 12    1661.562934
# 13    1174.211104
# 14     947.497130
# Name: AmtClaimsYr2, dtype: float64

# %%
# # Review Distributions of all numeric columns
# merged_pets.hist(figsize=(15,10))
# plt.subplots_adjust(hspace=0.5);

# %%
# # Isolate rows with high premiums for additional review
# high_prems = pets[pets['Premium'] > 200]

# # Review date distribution
# plt.figure(figsize=(6, 4))
# plt.title('Distribution of High Premiums')
# plt.hist(high_prems.Premium, bins = 20)
# plt.show()

# %%
# # Review the number of pets with high premiums by species
# high_prems.Species.value_counts()
